# %%
import sqlite3

# %%
conn = sqlite3.connect("fintraclai.db")

# %%
cur = conn.cursor()

# %%
import datetime

# %%
cur.execute('''
    create table user(
            user_id int primary key,
            user_name varchar(100),
            Gender char(10),
            Email varchar(100),
            password_hash text,
            create_at datetime
            )
    ''')

# %%
conn.commit()

# %%
cur.execute('''
    create table Verification(
            OTP_ID INT Primary key,
            User_id int,
            email_otp int,
            otp_exp float,
            otp_creation datetime,
            otp_status varchar(30) check( otp_status in ("verified", "not verified")),
            foreign key (user_id) references user(user_id)
            )
    ''')

# %%
conn.commit()

# %%
cur.execute('''
        CREATE TABLE INCOMEPROFILE(
            PROFILE_ID INT PRIMARY KEY,
            USER_ID INT,
            INCOME_TYPE VARCHAR(40) CHECK(INCOME_TYPE IN("SALARIED","PROFESSIONAL","BUSINESS","OTHERS")),
            MONTHLY_INCOME FLOAT,
            ADDITIONAL_INCOME_TYPE VARCHAR(50) CHECK(ADDITIONAL_INCOME_TYPE IN("STOCK","INVESTEMENTS","BUSINESS","OTHERS")),
            ADDITIONAL_MONTHLY_INCOME FLOAT,
            DEPENDANTS INT CHECK(DEPENDANTS<20),
            CREATED_AT DATETIME,
            UPDATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
        )
        ''')

# %%
cur.execute('''
        CREATE TABLE EXPENSEPROFILE(
            EXPENSE_ID INT PRIMARY KEY,
            USER_ID INT,
            GROCERIES FLOAT,
            TRAVEL FLOAT,
            MEDFIT FLOAT,
            LEP FLOAT,
            MONTHLY_RENT FLOAT,
            M_BILLS FLOAT,
            FASHION FLOAT,
            ENTERTAINMENT FLOAT,
            EDUCATION FLOAT,
            EMSAVING FLOAT,
            MISCELLANEOUS FLOAT,
            CREATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
        )
        ''')

# %%
cur.execute('''
        CREATE TABLE GOALS(
            GOALID INT PRIMARY KEY,
            USER_ID INT,
            GOAL_NAME VARCHAR(100),
            START_DATE DATETIME,
            END_DATE DATETIME,
            GOAL_AMOUNT FLOAT,
            MONTHLY_SAVING_T FLOAT,
            GOAL_STATUS VARCHAR(50) CHECK(GOAL_STATUS IN("ACTIVE","PAUSED","ACHIEVED","EXPIRED","INACTIVE")),
            CREATED_AT DATETIME,
            UPDATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID))
            

     
        ''')

# %%
cur.execute('''
        CREATE TABLE GOAL_HISTORY(
        HISTORY_ID INT PRIMARY KEY,
        GOALID INT,
        CREATED_AT DATETIME,
        SAVE_MONTH FLOAT,
        FOREIGN KEY(GOALID) REFERENCES GOALS(GOALID))
     
        ''')

# %%
cur.execute('''
    insert into user values(2, "surya","Male","mukkasuryateja@gmail.com", "bfweibuibyfvyywebiyebvyuieiu", "{datetime.datetime.now()}" )




     ''')

# %%
cur.execute('''select * from user''')
cur.fetchall()
# Out:
# [(1,
#   'john',
#   'Male',
#   'jhon@gmail.com',
#   'bfweibuiwebiyebvyuieiu',
#   '{datetime.datetime.now()}'),
#  (2,
#   'surya',
#   'Male',
#   'mukkasuryateja@gmail.com',
#   'bfweibuibyfvyywebiyebvyuieiu',
#   '{datetime.datetime.now()}')]

# %%
conn.commit()

# %%
cur.execute('''
    insert into verification values(1, 2,0246,4589478,"{datetime.datetime.now()}", "verified"  )




     ''')

# %%
conn.commit()

# %%
cur.execute("select * from verification")
cur.fetchall()
# Out:
# [(1, 2, 246, 4589478.0, '{datetime.datetime.now()}', 'verified'),
#  (2, 4, 3964, 1774699965.5636811, '2026-03-28 17:38:12.115158', 'verified')]

# %%
cur.execute("delete from user where user_id <>1")

# %%
conn.commit()

# %%
cur.execute("SELECT EMAIL,PASSWORD_HASH FROM USER")
cur.fetchall()
# Out:
# [('jhon@gmail.com', 'bfweibuiwebiyebvyuieiu'),
#  ('mukkasuryateja@gmail.com', 'bfweibuibyfvyywebiyebvyuieiu'),
#  ('mukkasryatja@gmail.com',
#   'scrypt:32768:8:1$6bKDQHfLs9KMZWmI$1ef504695872b5e1aa390fb9dc683927ce0230ac1db89467e83b8c6efe50de2bc8b673c57ce7b369f77b42085ef91c9f4428d19baf0ca435e419f70faae25a52'),
#  ('mukkasratja@gmail.com',
#   'scrypt:32768:8:1$z7x6galiowMBCL2r$bf241768d12621608e562b34e3721cd1108626324a9ee58f8eb03f23b28a15c816a327d9873b0285bfe49e7490a38fea4811e00cd5cdc606b7426c7a2f28d9b3'),
#  ('mukkagrps@gmail.com',
#   'scrypt:32768:8:1$Ap0gJ6dXKLzh8LmW$a09b64f32780ac508568956f27475b871832a12644109c526dfea361fb3c1a07bc8c71027a5863f10abb73d7d446af980437a22730de28ce3ed865d84687c8a9')]
