# %%
import sqlite3

# %%
conn = sqlite3.connect("fintraclai.db")

# %%
cur = conn.cursor()

# %%
import datetime

# %%
cur.execute('''
    create table user(
            user_id int primary key,
            user_name varchar(100),
            Gender char(10),
            Email varchar(100),
            password_hash text,
            create_at datetime
            )
    ''')

# %%
conn.commit()

# %%
cur.execute('''
    create table Verification(
            OTP_ID INT Primary key,
            User_id int,
            email_otp int,
            otp_exp float,
            otp_creation datetime,
            otp_status varchar(30) check( otp_status in ("verified", "not verified")),
            foreign key (user_id) references user(user_id)
            )
    ''')

# %%
conn.commit()

# %%
cur.execute('''
        CREATE TABLE INCOMEPROFILE(
            PROFILE_ID INT PRIMARY KEY,
            USER_ID INT,
            INCOME_TYPE VARCHAR(40) CHECK(INCOME_TYPE IN("SALARIED","PROFESSIONAL","BUSINESS","OTHERS")),
            MONTHLY_INCOME FLOAT,
            ADDITIONAL_INCOME_TYPE VARCHAR(50) CHECK(ADDITIONAL_INCOME_TYPE IN("STOCK","INVESTEMENTS","BUSINESS","OTHERS")),
            ADDITIONAL_MONTHLY_INCOME FLOAT,
            DEPENDANTS INT CHECK(DEPENDANTS<20),
            CREATED_AT DATETIME,
            UPDATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
        )
        ''')

# %%
cur.execute('''
        CREATE TABLE EXPENSEPROFILE(
            EXPENSE_ID INT PRIMARY KEY,
            USER_ID INT,
            GROCERIES FLOAT,
            TRAVEL FLOAT,
            MEDFIT FLOAT,
            LEP FLOAT,
            MONTHLY_RENT FLOAT,
            M_BILLS FLOAT,
            FASHION FLOAT,
            ENTERTAINMENT FLOAT,
            EDUCATION FLOAT,
            EMSAVING FLOAT,
            MISCELLANEOUS FLOAT,
            CREATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
        )
        ''')

# %%
cur.execute('''
        CREATE TABLE GOALS(
            GOALID INT PRIMARY KEY,
            USER_ID INT,
            GOAL_NAME VARCHAR(100),
            START_DATE DATETIME,
            END_DATE DATETIME,
            GOAL_AMOUNT FLOAT,
            MONTHLY_SAVING_T FLOAT,
            GOAL_STATUS VARCHAR(50) CHECK(GOAL_STATUS IN("ACTIVE","PAUSED","ACHIEVED","EXPIRED","INACTIVE")),
            CREATED_AT DATETIME,
            UPDATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID))
            

     
        ''')

# %%
cur.execute('''
        CREATE TABLE GOAL_HISTORY(
        HISTORY_ID INT PRIMARY KEY,
        GOALID INT,
        CREATED_AT DATETIME,
        SAVE_MONTH FLOAT,
        FOREIGN KEY(GOALID) REFERENCES GOALS(GOALID))
     
        ''')

# %%
cur.execute('''
    insert into user values(2, "surya","Male","mukkasuryateja@gmail.com", "bfweibuibyfvyywebiyebvyuieiu", "{datetime.datetime.now()}" )




     ''')

# %%
cur.execute('''select * from user''')
cur.fetchall()

# %%
conn.commit()

# %%
cur.execute('''
    insert into verification values(1, 2,0246,4589478,"{datetime.datetime.now()}", "verified"  )




     ''')

# %%
conn.commit()

# %%
cur.execute("select * from verification")
cur.fetchall()

# %%
cur.execute("delete from expenseprofile  where expense_id =1")

# %%
conn.commit()

# %%
cur.execute("SELECT EMAIL,PASSWORD_HASH FROM USER")
cur.fetchall()

# %%
cur.execute("select * from user")
cur.fetchall()

# %%
import numpy as np
